# %% [markdown]
# #Sobiye Olufemi Submission

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("/content/FoodBalanceSheet.csv", encoding="latin-1")

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
missing = df["Y2014"].isna().sum()
missing
# Out:
# 1589

# %%
total = len(df["Y2014"])
total
# Out:
# 60943

# %%
percent = round((missing/total)*100, 3)
percent
# Out:
# 2.607

# %%
corre = df[["Element Code", "Y2014",  "Y2015", "Y2016", "Y2017", "Y2018"]]

# %%
corre.corr()
# Out:
#               Element Code     Y2014     Y2015     Y2016     Y2017     Y2018
# Element Code      1.000000  0.024457  0.023889  0.023444  0.024254  0.024279
# Y2014             0.024457  1.000000  0.994647  0.996081  0.995230  0.994872
# Y2015             0.023889  0.994647  1.000000  0.995739  0.988048  0.988208
# Y2016             0.023444  0.996081  0.995739  1.000000  0.992785  0.992757
# Y2017             0.024254  0.995230  0.988048  0.992785  1.000000  0.998103
# Y2018             0.024279  0.994872  0.988208  0.992757  0.998103  1.000000

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df["Area"].nunique()
# Out:
# 49

# %%
df.groupby("Item").sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %%
df.groupby("Element").sum()
# Out:
#                                         Area Code  \
# Element
# Domestic supply quantity                   708993
# Export Quantity                            599910
# Fat supply quantity (g/capita/day)         675050
# Feed                                       176272
# Food                                       663295
# Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)        658446
# Import Quantity                            688174
# Losses                                     274353
# Other uses (non-food)                      235554
# Processing                                 271940
# Production                                 526751
# Protein supply quantity (g/capita/day)     675050
# Residuals                                  623271
# Seed                                       103537
# Stock Variation                            571566
# Total Population - Both sexes                6020
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
selected_columns = df[['Y2017', 'Area']]

grouped_data = selected_columns.groupby('Area').sum()

area_with= grouped_data.idxmax()[0]

# %%
area_with
# Out:
# 'Nigeria'

# %%
selected_columns = df[['Y2017', 'Area']]

grouped_data = selected_columns.groupby('Area').sum()

sorted_sums = grouped_data.sort_values(by='Y2017')

lowest_sum = sorted_sums.index[6]

# %%
lowest_sum
# Out:
# 'Guinea-Bissau'

# %%
df.shape
# Out:
# (60943, 12)

# %%
madagascar_2015 = df[(df['Area'] == 'Madagascar') & (df['Y2015'])]

total_protein_supply_2015 = madagascar_2015['Element'] == 'Protein supply quantity (g/capita/day)'.sum()

print("Total protein supply quantity in Madagascar in 2015:", total_protein_supply_2015)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-d308a7130b38> in <cell line: 3>()
#       1 madagascar_2015 = df[(df['Area'] == 'Madagascar') & (df['Y2015'])]
#       2
# ----> 3 total_protein_supply_2015 = madagascar_2015['Element'] == 'Protein supply quantity (g/capita/day)'.sum()
#       4
#       5 print("Total protein supply quantity in Madagascar in 2015:", total_protein_supply_2015)
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
list(df["Item"].unique())
# Out:
# ['Population',
#  'Grand Total',
#  'Vegetal Products',
#  'Animal Products',
#  'Cereals - Excluding Beer',
#  'Wheat and products',
#  'Rice and products',
#  'Barley and products',
#  'Maize and products',
#  'Rye and products',
#  'Oats',
#  'Millet and products',
#  'Sorghum and products',
#  'Cereals, Other',
#  'Starchy Roots',
#  'Cassava and products',
#  'Potatoes and products',
#  'Sweet potatoes',
#  'Yams',
#  'Roots, Other',
#  'Sugar Crops',
#  'Sugar cane',
#  'Sugar beet',
#  'Sugar & Sweeteners',
#  'Sugar (Raw Equivalent)',
#  'Sweeteners, Other',
#  'Honey',
#  'Pulses',
#  'Beans',
#  'Peas',
#  'Pulses, Other and products',
#  'Treenuts',
#  'Nuts and products',
#  'Oilcrops',
#  'Soyabeans',
#  'Groundnuts (Shelled Eq)',
#  'Sunflower seed',
#  'Rape and Mustardseed',
#  'Cottonseed',
#  'Coconuts - Incl Copra',
#  'Sesame seed',
#  'Olives (including preserved)',
#  'Oilcrops, Other',
#  'Vegetable Oils',
#  'Soyabean Oil',
#  'Groundnut Oil',
# ...
